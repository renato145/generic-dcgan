# %% [markdown]
# # Wasserstein GAN in Pytorch

# %%
import torch
import random
import numpy as np
import matplotlib.pyplot as plt
from time import time
from torchvision import datasets, transforms, utils
# %matplotlib inline

# %% [markdown]
# First, we, set up batch size, image size, and size of noise vector:

# %%
bs,sz,nz = 512,64,100
PATH_G = 'model2_g'
PATH_D = 'model2_d'

# %%
PATH = '/home/m20163692/data/lsun'
data = datasets.LSUN(db_path=PATH, classes=['church_outdoor_train'],
    transform=transforms.Compose([
        transforms.Scale(sz),
        transforms.CenterCrop(sz),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
]))

# %% [markdown]
# Even parallel processing is handling automatically by torch-vision.

# %%
dataloader = torch.utils.data.DataLoader(data, bs, True, num_workers=8)
n = len(dataloader); n
# Out:
# 247

# %%
next(iter(dataloader))[0].size()
# Out:
# torch.Size([512, 3, 64, 64])

# %% [markdown]
# Our activation function will be `tanh`, so we need to do some processing to view the generated images.

# %%
def show(img, fs=(8,8)):
    plt.figure(figsize = fs)
    plt.imshow(np.transpose((img/2+0.5).clamp(0,1).numpy(), (1,2,0)), interpolation='nearest')
    plt.show()

# %% [markdown]
# ## Create model

# %% [markdown]
# The CNN definitions are a little big for a notebook, so we import them.

# %%
import torch.nn as nn
from torch import optim
from torch.autograd import Variable
from dcgan_3conv import DCGAN_D, DCGAN_G

# %% [markdown]
# Pytorch uses `module.apply()` for picking an initializer.

# %%
def weights_init(m):
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)): 
        m.weight.data.normal_(0.0, 0.02)
    elif isinstance(m, nn.BatchNorm2d):
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

# %%
netG = DCGAN_G(sz, nz, 3, 64, 2, 1).cuda()
netG.apply(weights_init);

# %%
netD = DCGAN_D(sz, 3, 64, 2, 1).cuda()
netD.apply(weights_init);

# %% [markdown]
# Just some shortcuts to create tensors and variables.

# %%
from torch import FloatTensor as FT

def Var(*params):
    return Variable(FT(*params).cuda())

def create_noise(b): 
    return Variable(FT(b, nz, 1, 1).cuda().normal_(0, 1))

# %%
# Input placeholder
input = Var(bs, 3, sz, nz)
# Fixed noise used just for visualizing images when done
fixed_noise = create_noise(bs)
# The numbers 0 and -1
one = torch.FloatTensor([1]).cuda()
mone = one * -1

# %% [markdown]
# An optimizer needs to be told what variables to optimize. A module automatically keeps track of its variables.

# %%
optimizerD = optim.RMSprop(netD.parameters(), lr = 1e-4)
optimizerG = optim.RMSprop(netG.parameters(), lr = 1e-4)

# %% [markdown]
# One forward step and one backward step for D

# %%
def step_D(v, init_grad):
    err = netD(v).mean(0).view(1)
    err.backward(init_grad)
    return err

# %%
def make_trainable(net, val): 
    for p in net.parameters(): p.requires_grad = val

# %%
def train(niter, first=True):
    gen_iterations = 0
    save_flag = 1
    for epoch in range(niter):
        t0 = time()
        data_iter = iter(dataloader)
        i = 0
        while i < n:
            make_trainable(netD, True)
            d_iters = (100 if first and (gen_iterations < 25) or gen_iterations % 500 == 0 
                       else 5)
            # d_iters = 5

            j = 0
            while j < d_iters and i < n:
                j += 1; i += 1
                for p in netD.parameters(): p.data.clamp_(-0.01, 0.01)
                real = Variable(next(data_iter)[0].cuda())
                netD.zero_grad()
                errD_real = step_D(real, one)

                fake = netG(create_noise(real.size()[0]))
                input.data.resize_(real.size()).copy_(fake.data)
                errD_fake = step_D(input, mone)
                errD = errD_real - errD_fake
                optimizerD.step()
                print(f'[{i:04}] G-it:{gen_iterations:04} errD:{errD.data[0]}',
                      f'errDR:{errD_real.data[0]} errDF:{errD_fake.data[0]}', end='\r')

            make_trainable(netD, False)
            netG.zero_grad()
            errG = step_D(netG(create_noise(bs)), one)
            optimizerG.step()
            gen_iterations += 1
            if save_flag == -1:
                p_g = PATH_G + '_temp.pkl'
                p_d = PATH_D + '_temp.pkl'
            else:
                p_g = PATH_G + '.pkl'
                p_d = PATH_D + '.pkl'
            
#             torch.save(netG.state_dict(), p_g)
#             torch.save(netD.state_dict(), p_d)
            save_flag *= -1
            
        print('[%d/%d][%d/%d] Loss_D: %f Loss_G: %f Loss_D_real: %f Loss_D_fake %f (%.2fs)' % (
            epoch, niter, gen_iterations, n,
            errD.data[0], errG.data[0], errD_real.data[0], errD_fake.data[0], time() - t0))

# %%
# %%time
train(100000, True) # First run
# train(10000, False)
# Out:
# [0035] G-it:0000 errD:-1.111057996749878 errDR:-0.529228925704956 errDF:0.58182901144027712194904680772
# Process Process-14:
# Process Process-13:
# Traceback (most recent call last):
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-15:
# Process Process-12:
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Traceback (most recent call last):
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process Process-11:
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Traceback (most recent call last):
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Traceback (most recent call last):
# Process Process-16:
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 36, in __getitem__
#     with env.begin(write=False) as txn:
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 42, in __getitem__
#     img = Image.open(buf).convert('RGB')
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/PIL/Image.py", line 857, in convert
#     self.load()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/PIL/ImageFile.py", line 234, in load
#     n, err_code = decoder.decode(b)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Process Process-10:
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 37, in __getitem__
#     imgbuf = txn.get(self.keys[index])
# Traceback (most recent call last):
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
# KeyboardInterrupt
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 37, in __getitem__
#     imgbuf = txn.get(self.keys[index])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 37, in __getitem__
#     imgbuf = txn.get(self.keys[index])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
# Process Process-9:
# KeyboardInterrupt
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 37, in __getitem__
#     imgbuf = txn.get(self.keys[index])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 41, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 125, in __getitem__
#     img, _ = db[index]
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 37, in __getitem__
#     imgbuf = txn.get(self.keys[index])
# KeyboardInterrupt
#   File "/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torchvision-0.1.8-py3.6.egg/torchvision/datasets/lsun.py", line 37, in __getitem__
#     imgbuf = txn.get(self.keys[index])
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>()
#
# <ipython-input-16-bf8205e6d5a3> in train(niter, first)
#      20                 errD_real = step_D(real, one)
#      21
# ---> 22                 fake = netG(create_noise(real.size()[0]))
#      23                 input.data.resize_(real.size()).copy_(fake.data)
#      24                 errD_fake = step_D(input, mone)
#
# <ipython-input-11-bafde897aa70> in create_noise(b)
#       5
#       6 def create_noise(b):
# ----> 7     return Variable(FT(b, nz, 1, 1).cuda().normal_(0, 1))
#
# /home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      63         else:
#      64             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 65             return new_type(self.size()).copy_(self, async)
#      66
#      67
#
# KeyboardInterrupt:

# %%
# p_g = PATH_G + '.pkl'
# p_d = PATH_D + '.pkl'
# torch.save(netG.state_dict(), p_g)
# torch.save(netD.state_dict(), p_d)

# %% [markdown]
# ## View

# %%
# LOAD
netG.load_state_dict(torch.load(PATH_G + '.pkl'))
netD.load_state_dict(torch.load(PATH_D + '.pkl'))

# %%
fixed_noise = create_noise(64)
fake = netG(fixed_noise).data.cpu()
# show(random.choice(fake))
show(utils.make_grid(fake), (16,16))

# %% [markdown]
# ## Check interpolation

# %%
from IPython.display import HTML
from matplotlib import animation, rc

fig, ax = plt.subplots()

def animate(i):
    ax.imshow(np.transpose((interpolation[i]/2+0.5).clamp(0,1).numpy(), (1,2,0)), interpolation='nearest')

# %%
# get random image
noise_base = create_noise(1)
show(netG(noise_base).data.cpu()[0], (3,3))

# %%
n_imgs = 100
# noise = create_noise(1)
noise = noise_base.repeat(n_imgs,1,1,1)

# pick dimension
r_dim = random.randint(0, noise.size()[1] - 1)
print(f'choosen dim = {r_dim}')
noise[:,r_dim] = torch.linspace(-2, 2, n_imgs)

# get & show imgs
interpolation = netG(noise).data.cpu()
# Out:
# choosen dim = 61

# %%
# show(utils.make_grid(interpolation, nrow=int(np.sqrt(n_imgs))), (16,16))

# %%
anim = animation.FuncAnimation(fig, animate, frames=n_imgs, interval=100)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
show(utils.make_grid(iter(dataloader).next()[0][:64]), (16,16))
