# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = pd.read_csv('data_128//discriminator_log.csv')
g = pd.read_csv('data_128//generator_log.csv')

# %%
g[-2500:].plot(figsize=(16,4));

# %%
d[-2500:]['wgp_loss'].plot(figsize=(16,4));#, ylim=(-10,10));

# %%
d[-2500:].plot(figsize=(16,4))#, ylim=(-10,10));
plt.show()
display(d[-10:])
# Out:
#         wgp_loss   disc_real   disc_fake        gp
# 143049 -1.950629   -1.888827   -0.097983  0.036181
# 143050 -1.727257   -1.846104   -0.021815  0.140662
# 143051 -1.511225   -1.978879    0.421890  0.045764
# 143052 -1.935733   -2.503163    0.510937  0.056492
# 143053 -1.966288   -3.438092    1.357702  0.114101
# 143054 -1.799683   -2.819789    0.967772  0.052334
# 143055 -1.738372   -2.702915    0.806551  0.157993
# 143056 -2.121873   -2.394649    0.188919  0.083857
# 143057 -1.626669   -1.577225   -0.053406  0.003962
# 143058 -1.503948   -1.221104   -0.476473  0.193628
