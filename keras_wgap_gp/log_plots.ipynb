# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = pd.read_csv('data/discriminator_log.csv')
g = pd.read_csv('data/generator_log.csv')

# %%
g.plot(figsize=(16,4));

# %%
d['wgp_loss'].plot(figsize=(16,4), ylim=(-10,10));

# %%
d.plot(figsize=(16,4), ylim=(-10,10));
